# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
pd.set_option('display.max_rows', None)
data = pd.read_csv('Data_SEM_clear_v1.csv')
df=pd.DataFrame(data)
feature_names = df.keys()
all_feature_names= list(feature_names[2::])
num_feature_names = feature_names[5::]


x_num = df.iloc[:,5::]
standardScaler = StandardScaler()
x_num = pd.DataFrame(standardScaler.fit_transform(x_num),columns=num_feature_names)
x_cat = pd.DataFrame(df.iloc[:,2:5])
df_x = pd.concat([x_cat,x_num], axis=1)
df_x_orig = df_x.copy()
all_feature_names_orig = all_feature_names.copy()

# %%
# from sklearn.feature_selection import RFE
# from sklearn.ensemble import RandomForestClassifier
# x = df_x
# y =  df['HOMA_IR']
# # 假設 X_train 和 Y_train 是您的訓練資料特徵和標籤
# # 這裡假設 X_train 是您的特徵，Y_train 是您的標籤
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2,random_state=42)
# rf = RandomForestClassifier()
# rfe = RFE(rf)  # 不指定特徵數目
# rfe.fit(x_train, y_train)

# print("Number of selected features:", rfe.n_features_)
# print("Selected Features:", [feature for feature, support in zip(x_train.columns, rfe.support_) if support])

# %%
# from sklearn.metrics import precision_score,recall_score,roc_auc_score
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, precision_recall_curve
# x = importance = df_x[[feature for feature, support in zip(x_train.columns, rfe.support_) if support]]
# x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2,random_state=42)
# model = RandomForestClassifier()
# model.fit(x_train, y_train)
# y_pred = model.predict(x_test)
# y_pred_proba = model.predict_proba(x_test)[:,1]
# test_acc = accuracy_score(y_test, y_pred).round(5)
# cm = confusion_matrix(y_test, y_pred)
# print(pd.DataFrame(cm))
# print(classification_report(y_test, y_pred))
# print('正確率:', test_acc)

# %%
# from sklearn.metrics import accuracy_score
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import train_test_split
# import random

# x = df_x
# y = df['HOMA_IR']
# for count in range(500):
#     random_number = random.randint(0, 500)*count
#     x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=random_number)
#     step = []
#     rf = RandomForestClassifier(random_state=42)

#     # Initialize variables to keep track of best features and accuracy
#     best_features = []
#     best_accuracy = 0.0
#     # Stepwise feature selection
#     for i in range(len(x.columns)):
#         best_local_accuracy = 0.0
#         best_local_feature = None
        
#         # Try adding each feature to the existing best_features
#         for feature in x.columns:
#             if feature not in best_features:
#                 temp_features = best_features + [feature]
#                 rf.fit(x_train[temp_features], y_train)
#                 y_pred = rf.predict(x_test[temp_features])
#                 acc = accuracy_score(y_test, y_pred)
#                 if acc > best_local_accuracy:
#                     best_local_accuracy = acc
#                     best_local_feature = feature
#         # If adding a new feature increases accuracy, update the best_features
#         if best_local_accuracy > best_accuracy:
#             best_accuracy = best_local_accuracy
#             best_features.append(best_local_feature)
#             step.append(f"Selected features after {i+1} steps: {best_features}, Accuracy: {best_accuracy}")
#         else:
#             break  # Stop if adding more features doesn't increase accuracy


#     if best_accuracy>0.85:
#         print("Best selected features:", best_features)
#         print("Best evaluation metric:", best_accuracy)
#         # Train the final model using the best selected features
#         from sklearn.metrics import confusion_matrix, classification_report
#         final_rf = RandomForestClassifier(random_state=42)
#         final_rf.fit(x_train[best_features], y_train)
#         y_pred_final = final_rf.predict(x_test[best_features])
#         cm = confusion_matrix(y_test, y_pred_final)
#         print(pd.DataFrame(cm))
#         print("Classification Report:")
#         print(classification_report(y_test, y_pred_final))
#         print("Final random_state used:", random_number)
#         for s in step:
#             print(s)
#             print("\n")
#         break

# %%
# from sklearn.metrics import accuracy_score
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import train_test_split
# import random

# x = df_x
# y = df['HOMA_IR']
# for count in range(500):
#     random_number = random.randint(0, 500)*count
#     x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=random_number)
#     step = []
#     rf = RandomForestClassifier(random_state=42)

#     # Initialize variables to keep track of best features and accuracy
#     best_features = []
#     best_accuracy = 0.0
#     # Stepwise feature selection
#     for i in range(len(x.columns)):
#         best_local_accuracy = 0.0
#         best_local_feature = None
        
#         # Try adding each feature to the existing best_features
#         for feature in x.columns:
#             if feature not in best_features:
#                 temp_features = best_features + [feature]
#                 rf.fit(x_train[temp_features], y_train)
#                 y_pred = rf.predict(x_test[temp_features])
#                 acc = accuracy_score(y_test, y_pred)
#                 if acc > best_local_accuracy:
#                     best_local_accuracy = acc
#                     best_local_feature = feature
#         # If adding a new feature increases accuracy, update the best_features
#         if best_local_accuracy > best_accuracy:
#             best_accuracy = best_local_accuracy
#             best_features.append(best_local_feature)
#             step.append(f"Selected features after {i+1} steps: {best_features}, Accuracy: {best_accuracy}")
#         else:
#             step.append(f"Selected features after {i+1} steps: {temp_features}, Accuracy: {acc}")
#             break  # Stop if adding more features doesn't increase accuracy


#     if best_accuracy>0.80:
#         print("Best selected features:", best_features)
#         print("Best evaluation metric:", best_accuracy)
#         # Train the final model using the best selected features
#         from sklearn.metrics import confusion_matrix, classification_report
#         final_rf = RandomForestClassifier(random_state=42)
#         final_rf.fit(x_train[best_features], y_train)
#         y_pred_final = final_rf.predict(x_test[best_features])
#         cm = confusion_matrix(y_test, y_pred_final)
#         print(pd.DataFrame(cm))
#         print("Classification Report:")
#         print(classification_report(y_test, y_pred_final))
#         print("Final random_state used:", random_number)
#         for s in step:
#             print(s)
#             print("\n")
#         break
# Out:
# Best selected features: ['WHR', 'BUN', 'NMBP', 'group', 'Vo2max', 'NDBP']
# Best evaluation metric: 0.8023255813953488
#     0   1
# 0  25  13
# 1   4  44
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.66      0.75        38
#            1       0.77      0.92      0.84        48
#
#     accuracy                           0.80        86
#    macro avg       0.82      0.79      0.79        86
# weighted avg       0.81      0.80      0.80        86
#
# Final random_state used: 2070
# Selected features after 1 steps: ['WHR'], Accuracy: 0.686046511627907
#
#
# Selected features after 2 steps: ['WHR', 'BUN'], Accuracy: 0.6976744186046512
#
#
# Selected features after 3 steps: ['WHR', 'BUN', 'NMBP'], Accuracy: 0.7209302325581395
#
#
# Selected features after 4 steps: ['WHR', 'BUN', 'NMBP', 'group'], Accuracy: 0.7558139534883721
#
#
# Selected features after 5 steps: ['WHR', 'BUN', 'NMBP', 'group', 'Vo2max'], Accuracy: 0.7906976744186046
#
#
# Selected features after 6 steps: ['WHR', 'BUN', 'NMBP', 'group', 'Vo2max', 'NDBP'], Accuracy: 0.8023255813953488
#
#
# Selected features after 7 steps: ['WHR', 'BUN', 'NMBP', 'group', 'Vo2max', 'NDBP', 'DLCOPre'], Accuracy: 0.7325581395348837

# %%
# from sklearn.metrics import accuracy_score
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import train_test_split
# import random

# x = df_x
# y = df['HOMA_IR']
# for count in range(500):
#     random_number = random.randint(0, 500)*count
#     x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=random_number)
#     step = []
#     rf = RandomForestClassifier(random_state=42)

#     # Initialize variables to keep track of best features and accuracy
#     best_features = []
#     best_accuracy = 0.0
#     # Stepwise feature selection
#     for i in range(len(x.columns)):
#         best_local_accuracy = 0.0
#         best_local_feature = None
        
#         # Try adding each feature to the existing best_features
#         for feature in x.columns:
#             if feature not in best_features:
#                 temp_features = best_features + [feature]
#                 rf.fit(x_train[temp_features], y_train)
#                 y_pred = rf.predict(x_test[temp_features])
#                 acc = accuracy_score(y_test, y_pred)
#                 if acc > best_local_accuracy:
#                     best_local_accuracy = acc
#                     best_local_feature = feature
#         # If adding a new feature increases accuracy, update the best_features
#         if best_local_accuracy > best_accuracy:
#             best_accuracy = best_local_accuracy
#             best_features.append(best_local_feature)
#             step.append(f"Selected features after {i+1} steps: {best_features}, Accuracy: {best_accuracy}")
#         else:
#             step.append(f"Selected features after {i+1} steps: {temp_features}, Accuracy: {acc}")
#             break  # Stop if adding more features doesn't increase accuracy


#     if best_accuracy>0.80:
#         print("Best selected features:", best_features)
#         print("Best evaluation metric:", best_accuracy)
#         # Train the final model using the best selected features
#         from sklearn.metrics import confusion_matrix, classification_report
#         final_rf = RandomForestClassifier(random_state=42)
#         final_rf.fit(x_train[best_features], y_train)
#         y_pred_final = final_rf.predict(x_test[best_features])
#         cm = confusion_matrix(y_test, y_pred_final)
#         print(pd.DataFrame(cm))
#         print("Classification Report:")
#         print(classification_report(y_test, y_pred_final))
#         print("Final random_state used:", random_number)
#         for s in step:
#             print(s)
#             print("\n")
#         break
# Out:
# Best selected features: ['WHR', 'group', 'FVCPre', 'NDBP', 'CHO', 'PLM', 'BUN']
# Best evaluation metric: 0.8023255813953488
#     0   1
# 0  26  10
# 1   7  43
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.79      0.72      0.75        36
#            1       0.81      0.86      0.83        50
#
#     accuracy                           0.80        86
#    macro avg       0.80      0.79      0.79        86
# weighted avg       0.80      0.80      0.80        86
#
# Final random_state used: 6304
# Selected features after 1 steps: ['WHR'], Accuracy: 0.6744186046511628
#
#
# Selected features after 2 steps: ['WHR', 'group'], Accuracy: 0.686046511627907
#
#
# Selected features after 3 steps: ['WHR', 'group', 'FVCPre'], Accuracy: 0.7093023255813954
#
#
# Selected features after 4 steps: ['WHR', 'group', 'FVCPre', 'NDBP'], Accuracy: 0.7209302325581395
#
#
# Selected features after 5 steps: ['WHR', 'group', 'FVCPre', 'NDBP', 'CHO'], Accuracy: 0.7441860465116279
#
#
# Selected features after 6 steps: ['WHR', 'group', 'FVCPre', 'NDBP', 'CHO', 'PLM'], Accuracy: 0.7790697674418605
#
#
# Selected features after 7 steps: ['WHR', 'group', 'FVCPre', 'NDBP', 'CHO', 'PLM', 'BUN'], Accuracy: 0.8023255813953488
#
#
# Selected features after 8 steps: ['WHR', 'group', 'FVCPre', 'NDBP', 'CHO', 'PLM', 'BUN', 'DLCOPre'], Accuracy: 0.7093023255813954
